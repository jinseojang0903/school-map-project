# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import re

# 데이터 불러오기
df = pd.read_csv("전라남도_병원_의원현황.csv", encoding="cp949")

# 주소 컬럼 만들기
df["주소"] = df["소재지(도로명)"].fillna(df["소재지(지번)"])

def clean_address_v2(addr):
    if pd.isna(addr): return ""
    
    # 1. 괄호, 콤마 제거
    addr = re.sub(r"\(.*?\)", "", addr)
    addr = re.sub(r",.*", "", addr)
    
    # 2. '번지', '호', '층' 제거
    addr = re.sub(r"\d+번지", "", addr)
    addr = re.sub(r"\d+호", "", addr)
    addr = re.sub(r"\d+층", "", addr)

    # 3. '리'로 끝나는 지명 + 숫자 제거
    addr = re.sub(r"리\s*\d+(-\d+)?", "리", addr)
    
    # 4. 띄어쓰기 정리
    addr = re.sub(r"\s+", " ", addr)
    
    return addr.strip()


# 전처리된 주소 컬럼
df["정리된주소"] = df["주소"].apply(clean_address)

# Geocoder 설정
geolocator = Nominatim(user_agent="jeonnam-hospital-test")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# 상위 10개만 테스트
subset = df.head(100).copy()
subset["위도"] = None
subset["경도"] = None
count = 0
# 위경도 출력
for i in range(len(subset)):
    addr = subset.loc[i, "정리된주소"]
    print(f"[{i+1}/10] 주소: {addr}")
    try:
        location = geocode(addr)
        if location:
            lat = location.latitude
            lon = location.longitude
            subset.at[i, "위도"] = lat
            subset.at[i, "경도"] = lon
            print(f"   → 위도: {lat}, 경도: {lon}")
        else:
            print("   → ❌ 위경도 찾을 수 없음")
            count += 1
    except Exception as e:
        print(f"   → ⚠️ 오류: {e}")
print("총 오류 수:", count)
# Out:
# [1/10] 주소: 전라남도 신안군 도초면 서남문로 1515-16
#    → 위도: 34.7071294, 경도: 125.939454
# [2/10] 주소: 전라남도 영광군 영광읍 신남로 178
#    → 위도: 35.2760756, 경도: 126.5015298
# [3/10] 주소: 전라남도 담양군 고서면 원등1길 11
#    → 위도: 35.2236195, 경도: 126.9749057
# [4/10] 주소: 전라남도 담양군 용면 추월산로 369
#    → 위도: 35.3650021, 경도: 126.9874564
# [5/10] 주소: 전라남도 담양군 봉산면 신학길 8
#    → 위도: 35.2744109, 경도: 126.9555414
# [6/10] 주소: 전라남도 담양군 월산면 도개길 15-36
#    → 위도: 35.3401114, 경도: 126.9561917
# [7/10] 주소: 전라남도 완도군 완도읍 개포로62번길 33
#    → 위도: 34.3180205, 경도: 126.7476958
# [8/10] 주소: 전라남도 고흥군 도양읍 녹동남촌1길 8
#    → 위도: 34.5284639, 경도: 127.1383688
# [9/10] 주소: 전라남도 고흥군 고흥읍 터미널길 33
#    → 위도: 34.6054179, 경도: 127.2801869
# [10/10] 주소: 전라남도 고흥군 고흥읍 홍교길 13-1
#    → ❌ 위경도 찾을 수 없음
# [11/10] 주소: 전라남도 고흥군 고흥읍 원동남계길 26
#    → 위도: 34.6092748, 경도: 127.2873108
# [12/10] 주소: 전라남도 영광군 영광읍 신남로 168
#    → 위도: 35.2760756, 경도: 126.5015298
# [13/10] 주소: 가곡동977-6
#    → ❌ 위경도 찾을 수 없음
# [14/10] 주소: 전라남도 담양군 대전면 덕진옥산길 6
#    → ❌ 위경도 찾을 수 없음
# [15/10] 주소: 전라남도 여수시 무선로 6
#    → 위도: 34.7755283, 경도: 127.6536998
# [16/10] 주소: 전라남도 여수시 새터로 104
#    → 위도: 34.7596978, 경도: 127.6762747
# [17/10] 주소: 전라남도 나주시 세지면 성산덕산길 9-14
#    → ❌ 위경도 찾을 수 없음
# [18/10] 주소: 전라남도 나주시 왕곡면 예향로 3320
#    → 위도: 34.9857261, 경도: 126.7044022
# [19/10] 주소: 전라남도 여수시 시청로 34
#    → 위도: 34.7640484, 경도: 127.6627327
# [20/10] 주소: 전라남도 목포시 삼학로 329
#    → 위도: 34.7903022, 경도: 126.3865421
# [21/10] 주소: 전라남도 여수시 무선로 6
#    → 위도: 34.7755283, 경도: 127.6536998
# [22/10] 주소: 전라남도 보성군 벌교읍 채동선로 224
#    → 위도: 34.8367194, 경도: 127.3424956
# [23/10] 주소: 전라남도 광양시 중동 1676-6
#    → 위도: 34.9379939, 경도: 127.6923994
# [24/10] 주소: 전라남도 순천시 순광로 6
#    → 위도: 34.9617748, 경도: 127.5377233
# [25/10] 주소: 전라남도 광양시 광양읍 칠성로 45
#    → 위도: 34.9792345, 경도: 127.5806222
# [26/10] 주소: 전라남도 목포시 번화로 39-1
#    → 위도: 34.7862198, 경도: 126.3843138
# [27/10] 주소: 전라남도 고흥군 금산면 오천서당길 14-11
#    → ❌ 위경도 찾을 수 없음
# [28/10] 주소: 전라남도 고흥군 금산면 평산1길 14
#    → ❌ 위경도 찾을 수 없음
# [29/10] 주소: 전라남도 고흥군 금산면 연홍길 30
#    → ❌ 위경도 찾을 수 없음
# [30/10] 주소: 전라남도 신안군 안좌면 김환기길 3-2
#    → 위도: 34.7538435, 경도: 126.1252063
# [31/10] 주소: 전라남도 여수시 여서1로 87
#    → 위도: 34.7540104, 경도: 127.7065686
# [32/10] 주소: 전라남도 여수시 소라면 죽림로 21
#    → 위도: 34.7630307, 경도: 127.6397707
# [33/10] 주소: 전라남도 여수시 소라면 죽림로 3
#    → 위도: 34.7630307, 경도: 127.6397707
# [34/10] 주소: 전라남도 여수시 소라면 상사길 21
#    → ❌ 위경도 찾을 수 없음
# [35/10] 주소: 전라남도 여수시 돌산읍 향일암로 269-6
#    → 위도: 34.6396037, 경도: 127.7877619
# [36/10] 주소: 전라남도 여수시 돌산읍 돌산로 2080-8
#    → 위도: 34.6783046, 경도: 127.7646508
# [37/10] 주소: 전라남도 여수시 묘도10길 6
#    → ❌ 위경도 찾을 수 없음
# [38/10] 주소: 전라남도 여수시 돌산읍 평사로 560-6
#    → 위도: 34.6590978, 경도: 127.7347876
# [39/10] 주소: 전라남도 여수시 율촌면 상봉1길 1
#    → ❌ 위경도 찾을 수 없음
# [40/10] 주소: 전라남도 여수시 화정면 마파지길 17
#    → ❌ 위경도 찾을 수 없음
# [41/10] 주소: 전라남도 여수시 남면 화태길 28
#    → ❌ 위경도 찾을 수 없음
# [42/10] 주소: 전라남도 목포시 상락동2가 6번지
#    → ❌ 위경도 찾을 수 없음
# [43/10] 주소: 전라남도 장성군 장성읍 영천리 930번지 3호
#    → ❌ 위경도 찾을 수 없음
# [44/10] 주소: 전라남도 화순군 화순읍 쌍충로 118-5
#    → 위도: 35.0530025, 경도: 126.9806548
# [45/10] 주소: 전라남도 순천시 중앙로 314
#    → 위도: 34.975612, 경도: 127.4821844
# [46/10] 주소: 전라남도 광양시 광양읍 칠성로 56
#    → 위도: 34.9792345, 경도: 127.5806222
# [47/10] 주소: 전라남도 해남군 옥천면 해강로 24
#    → 위도: 34.5708155, 경도: 126.6721756
# [48/10] 주소: 전라남도 구례군 산동면 이촌길 4
#    → ❌ 위경도 찾을 수 없음
# [49/10] 주소: 전라남도 해남군 화원면 청용1길 4
#    → 위도: 34.6737333, 경도: 126.3277993
# [50/10] 주소: 전라남도 장흥군 장흥읍 건산리 386-3
#    → ❌ 위경도 찾을 수 없음
# [51/10] 주소: 전라남도 해남군 북평면 남창리 352번지
#    → ❌ 위경도 찾을 수 없음
# [52/10] 주소: 전라남도 나주시 예향로 3811
#    → 위도: 34.9949163, 경도: 126.7133811
# [53/10] 주소: 구례군구례읍봉동리309-4
#    → ❌ 위경도 찾을 수 없음
# [54/10] 주소: 구례군구례읍봉동리333-2
#    → ❌ 위경도 찾을 수 없음
# [55/10] 주소: 전라남도 여수시 소호로 659
#    → 위도: 34.743087, 경도: 127.6512073
# [56/10] 주소: 전라남도 영광군 묘량면 묘량로 283
#    → 위도: 35.2641272, 경도: 126.5445463
# [57/10] 주소: 전라남도 광양시 옥룡면 내천길 4
#    → ❌ 위경도 찾을 수 없음
# [58/10] 주소: 전라남도 해남군 해남읍 중앙2로 91
#    → 위도: 34.5674274, 경도: 126.595981
# [59/10] 주소: 전라남도 해남군 해남읍 해리 458-1
#    → ❌ 위경도 찾을 수 없음
# [60/10] 주소: 전라남도 여수시 성산로 5
#    → 위도: 34.7775249, 경도: 127.6470516
# [61/10] 주소: 전라남도 광양시 광양읍 인동리 411번지 10호
#    → ❌ 위경도 찾을 수 없음
# [62/10] 주소: 전라남도 영암군 삼호읍 세가래1길 10-6
#    → 위도: 34.7480189, 경도: 126.4752938
# [63/10] 주소: 전라남도 강진군 신전면 운주로 331
#    → ❌ 위경도 찾을 수 없음
# [64/10] 주소: 전라남도 영암군 영암읍 오리정길 39
#    → ❌ 위경도 찾을 수 없음
# [65/10] 주소: 전라남도 강진군 대구면 계율길 41
#    → ❌ 위경도 찾을 수 없음
# [66/10] 주소: 전라남도 광양시 광영로 46
#    → 위도: 34.9638326, 경도: 127.7164616
# [67/10] 주소: 전라남도 광양시 광양읍 숲샘길 129
#    → 위도: 34.9708239, 경도: 127.5853624
# [68/10] 주소: 전라남도 목포시 청호로 172
#    → 위도: 34.8061784, 경도: 126.3737988
# [69/10] 주소: 전라남도 목포시 영산로 347
#    → 위도: 34.8396483, 경도: 126.4236511
# [70/10] 주소: 전라남도 목포시 부흥로 80
#    → ❌ 위경도 찾을 수 없음
# [71/10] 주소:
#    → ❌ 위경도 찾을 수 없음
# [72/10] 주소: 전라남도 여수시 남면 금오로 858
#    → 위도: 34.5276261, 경도: 127.769361
# [73/10] 주소: 전라남도 목포시 상동 991-2번지
#    → ❌ 위경도 찾을 수 없음
# [74/10] 주소: 전라남도 목포시 연산동 1262-2번지
#    → ❌ 위경도 찾을 수 없음
# [75/10] 주소: 전라남도 여수시 화양면 화양로 1436-5
#    → 위도: 34.7347, 경도: 127.6225471
# [76/10] 주소: 전라남도 순천시 왕지로 39
#    → ❌ 위경도 찾을 수 없음
# [77/10] 주소: 전라남도 강진군 강진읍 평동2길 30
#    → 위도: 34.6379967, 경도: 126.7680296
# [78/10] 주소: 전라남도 순천시 해룡면 향매로 67
#    → 위도: 34.9319354, 경도: 127.5557666
# [79/10] 주소: 전라남도 여수시 여서1로 62
#    → 위도: 34.7540104, 경도: 127.7065686
# [80/10] 주소: 전라남도 여수시 쌍봉로 372
#    → 위도: 34.7658561, 경도: 127.6665191
# [81/10] 주소: 전라남도 목포시 영산로 559
#    → 위도: 34.8396483, 경도: 126.4236511
# [82/10] 주소: 전라남도 화순군 화순읍 교리 100번지 10호
#    → ❌ 위경도 찾을 수 없음
# [83/10] 주소: 전라남도 순천시 오천7길 28
#    → 위도: 34.9351779, 경도: 127.4942651
# [84/10] 주소: 전라남도 화순군 화순읍 교리 100번지 14호
#    → ❌ 위경도 찾을 수 없음
# [85/10] 주소: 전라남도 화순군 화순읍 칠충로 145
#    → 위도: 35.061523, 경도: 126.9837294
# [86/10] 주소: 전라남도 화순군 화순읍 자치샘로 48
#    → 위도: 35.0610383, 경도: 126.9861249
# [87/10] 주소: 전라남도 화순군 화순읍 향청리 83번지 1호
#    → ❌ 위경도 찾을 수 없음
# [88/10] 주소: 전라남도 목포시 용해지구로 12
#    → 위도: 34.8175501, 경도: 126.3942735
# [89/10] 주소: 전라남도 화순군 춘양면 석정리 573번지 16호
#    → ❌ 위경도 찾을 수 없음
# [90/10] 주소: 전라남도 여수시 봉산동 269-43
#    → 위도: 34.7351874, 경도: 127.7230575
# [91/10] 주소: 전라남도 여수시 문수동 479-1
#    → ❌ 위경도 찾을 수 없음
# [92/10] 주소: 전라남도 장성군 장성읍 영천로 125-1
#    → ❌ 위경도 찾을 수 없음
# [93/10] 주소: 전라남도 장성군 장성읍 영천로 208-1
#    → ❌ 위경도 찾을 수 없음
# [94/10] 주소: 전라남도 장성군 장성읍 영천로 128
#    → ❌ 위경도 찾을 수 없음
# [95/10] 주소: 전라남도 완도군 보길면 청별길 26-2
#    → 위도: 34.16977, 경도: 126.5671831
# [96/10] 주소: 전라남도 목포시 비파로51번길 31
#    → ❌ 위경도 찾을 수 없음
# [97/10] 주소: 전라남도 보성군 보성읍 현충로 23-1
#    → 위도: 34.7679367, 경도: 127.0823852
# [98/10] 주소: 전라남도 완도군 생일면 생일로 590-32
#    → 위도: 34.3371125, 경도: 126.9956297
# [99/10] 주소: 전라남도 순천시 황전면 괴목길 97
#    → ❌ 위경도 찾을 수 없음
# [100/10] 주소: 전라남도 순천시 연향중앙상가길 29
#    → 위도: 34.9520692, 경도: 127.5195632
# 총 오류 수: 40

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# 1) 데이터 불러오기
df = pd.read_csv("전라남도_병원_의원현황.csv", encoding="cp949")

# 2) 주소 컬럼 생성 (도로명 우선, 없으면 지번)
df["주소"] = df["소재지(도로명)"].fillna(df["소재지(지번)"])

# 3) 지오코더 설정
geolocator = Nominatim(user_agent="jeonnam-hospital-test")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)   # 1초 간격 호출

# 4) 테스트용 상위 100개만 복사
subset = df.head(100).copy()
subset["위도"] = None
subset["경도"] = None

error_cnt = 0
total = len(subset)

for i, row in subset.iterrows():
    addr = row["주소"]
    print(f"[{i+1}/{total}] 주소: {addr}")
    try:
        location = geocode(addr)
        if location:
            subset.at[i, "위도"] = location.latitude
            subset.at[i, "경도"] = location.longitude
            print(f"   → 위도: {location.latitude}, 경도: {location.longitude}")
        else:
            print("   → ❌ 위경도 찾을 수 없음")
            error_cnt += 1
    except Exception as e:
        print(f"   → ⚠️ 오류: {e}")
        error_cnt += 1

print("총 오류 수:", error_cnt)

# 필요하면 결과 저장
# subset.to_csv("전남_병원_위경도_100건.csv", index=False, encoding="utf-8-sig")
# Out:
# [1/100] 주소: 전라남도 신안군 도초면 서남문로 1515-16
#    → 위도: 34.7071294, 경도: 125.939454
# [2/100] 주소: 전라남도 영광군 영광읍 신남로 178, 3층
#    → ❌ 위경도 찾을 수 없음
# [3/100] 주소: 전라남도 담양군 고서면 원등1길 11
#    → 위도: 35.2236195, 경도: 126.9749057
# [4/100] 주소: 전라남도 담양군 용면 추월산로 369
#    → 위도: 35.3650021, 경도: 126.9874564
# [5/100] 주소: 전라남도 담양군 봉산면 신학길 8, 봉산면 보건지소
#    → ❌ 위경도 찾을 수 없음
# [6/100] 주소: 전라남도 담양군 월산면 도개길 15-36, 월산 보건지소
#    → ❌ 위경도 찾을 수 없음
# [7/100] 주소: 전라남도 완도군 완도읍 개포로62번길 33, 2층 (금화상사, 아트피아)
#    → ❌ 위경도 찾을 수 없음
# [8/100] 주소: 전라남도 고흥군 도양읍 녹동남촌1길 8, 소매점 2층
#    → ❌ 위경도 찾을 수 없음
# [9/100] 주소: 전라남도 고흥군 고흥읍 터미널길 33, 치과병원
#    → ❌ 위경도 찾을 수 없음
# [10/100] 주소: 전라남도 고흥군 고흥읍 홍교길 13-1
#    → ❌ 위경도 찾을 수 없음
# [11/100] 주소: 전라남도 고흥군 고흥읍 원동남계길 26
#    → 위도: 34.6092748, 경도: 127.2873108
# [12/100] 주소: 전라남도 영광군 영광읍 신남로 168, 2층
#    → ❌ 위경도 찾을 수 없음
# [13/100] 주소: 가곡동977-6(2층)
#    → ❌ 위경도 찾을 수 없음
# [14/100] 주소: 전라남도 담양군 대전면 덕진옥산길 6, 보건진료소
#    → ❌ 위경도 찾을 수 없음
# [15/100] 주소: 전라남도 여수시 무선로 6 (학동, 이레타운)
#    → ❌ 위경도 찾을 수 없음
# [16/100] 주소: 전라남도 여수시 새터로 104, 2층 (신기동)
#    → ❌ 위경도 찾을 수 없음
# [17/100] 주소: 전라남도 나주시 세지면 성산덕산길 9-14 (세지성산보건진료소)
#    → ❌ 위경도 찾을 수 없음
# [18/100] 주소: 전라남도 나주시 왕곡면 예향로 3320 (왕곡신원보건진료소)
#    → ❌ 위경도 찾을 수 없음
# [19/100] 주소: 전라남도 여수시 시청로 34, 203호 (학동, 이레타운)
#    → ❌ 위경도 찾을 수 없음
# [20/100] 주소: 전라남도 목포시 삼학로 329, 2층 (용해동)
#    → ❌ 위경도 찾을 수 없음
# [21/100] 주소: 전라남도 여수시 무선로 6, 302-1호 (학동, 이레타운)
#    → ❌ 위경도 찾을 수 없음
# [22/100] 주소: 전라남도 보성군 벌교읍 채동선로 224, 2층
#    → ❌ 위경도 찾을 수 없음
# [23/100] 주소: 전라남도 광양시 중동 1676-6
#    → 위도: 34.9379939, 경도: 127.6923994
# [24/100] 주소: 전라남도 순천시 순광로 6, 2~3층 (조례동)
#    → ❌ 위경도 찾을 수 없음
# [25/100] 주소: 전라남도 광양시 광양읍 칠성로 45, 3층
#    → ❌ 위경도 찾을 수 없음
# [26/100] 주소: 전라남도 목포시 번화로 39-1, 1~2층 (중앙동1가)
#    → ❌ 위경도 찾을 수 없음
# [27/100] 주소: 전라남도 고흥군 금산면 오천서당길 14-11
#    → ❌ 위경도 찾을 수 없음
# [28/100] 주소: 전라남도 고흥군 금산면 평산1길 14
#    → ❌ 위경도 찾을 수 없음
# [29/100] 주소: 전라남도 고흥군 금산면 연홍길 30
#    → ❌ 위경도 찾을 수 없음
# [30/100] 주소: 전라남도 신안군 안좌면 김환기길 3-2
#    → 위도: 34.7538435, 경도: 126.1252063
# [31/100] 주소: 전라남도 여수시 여서1로 87 (여서동)
#    → ❌ 위경도 찾을 수 없음
# [32/100] 주소: 전라남도 여수시 소라면 죽림로 21, 2층
#    → ❌ 위경도 찾을 수 없음
# [33/100] 주소: 전라남도 여수시 소라면 죽림로 3
#    → 위도: 34.7630307, 경도: 127.6397707
# [34/100] 주소: 전라남도 여수시 소라면 상사길 21
#    → ❌ 위경도 찾을 수 없음
# [35/100] 주소: 전라남도 여수시 돌산읍 향일암로 269-6
#    → 위도: 34.6396037, 경도: 127.7877619
# [36/100] 주소: 전라남도 여수시 돌산읍 돌산로 2080-8
#    → 위도: 34.6783046, 경도: 127.7646508
# [37/100] 주소: 전라남도 여수시 묘도10길 6 (묘도동)
#    → ❌ 위경도 찾을 수 없음
# [38/100] 주소: 전라남도 여수시 돌산읍 평사로 560-6
#    → 위도: 34.6590978, 경도: 127.7347876
# [39/100] 주소: 전라남도 여수시 율촌면 상봉1길 1 (상봉보건 진료소)
#    → ❌ 위경도 찾을 수 없음
# [40/100] 주소: 전라남도 여수시 화정면 마파지길 17
#    → ❌ 위경도 찾을 수 없음
# [41/100] 주소: 전라남도 여수시 남면 화태길 28
#    → ❌ 위경도 찾을 수 없음
# [42/100] 주소: 전라남도 목포시 상락동2가 6번지
#    → ❌ 위경도 찾을 수 없음
# [43/100] 주소: 전라남도 장성군 장성읍 영천리 930번지 3호
#    → ❌ 위경도 찾을 수 없음
# [44/100] 주소: 전라남도 화순군 화순읍 쌍충로 118-5
#    → 위도: 35.0530025, 경도: 126.9806548
# [45/100] 주소: 전라남도 순천시 중앙로 314, 2~3층 (가곡동)
#    → ❌ 위경도 찾을 수 없음
# [46/100] 주소: 전라남도 광양시 광양읍 칠성로 56, 4,5층
#    → ❌ 위경도 찾을 수 없음
# [47/100] 주소: 전라남도 해남군 옥천면 해강로 24
#    → 위도: 34.5708155, 경도: 126.6721756
# [48/100] 주소: 전라남도 구례군 산동면 이촌길 4 (이평보건진료소)
#    → ❌ 위경도 찾을 수 없음
# [49/100] 주소: 전라남도 해남군 화원면 청용1길 4
#    → 위도: 34.6737333, 경도: 126.3277993
# [50/100] 주소: 전라남도 장흥군 장흥읍 건산리 386-3
#    → ❌ 위경도 찾을 수 없음
# [51/100] 주소: 전라남도 해남군 북평면 남창리 352번지
#    → ❌ 위경도 찾을 수 없음
# [52/100] 주소: 전라남도 나주시 예향로 3811 (이창동)
#    → ❌ 위경도 찾을 수 없음
# [53/100] 주소: 구례군구례읍봉동리309-4
#    → ❌ 위경도 찾을 수 없음
# [54/100] 주소: 구례군구례읍봉동리333-2
#    → ❌ 위경도 찾을 수 없음
# [55/100] 주소: 전라남도 여수시 소호로 659, 3층 (안산동, 부영상가)
#    → ❌ 위경도 찾을 수 없음
# [56/100] 주소: 전라남도 영광군 묘량면 묘량로 283
#    → 위도: 35.2641272, 경도: 126.5445463
# [57/100] 주소: 전라남도 광양시 옥룡면 내천길 4
#    → ❌ 위경도 찾을 수 없음
# [58/100] 주소: 전라남도 해남군 해남읍 중앙2로 91
#    → 위도: 34.5674274, 경도: 126.595981
# [59/100] 주소: 전라남도 해남군 해남읍 해리 458-1
#    → ❌ 위경도 찾을 수 없음
# [60/100] 주소: 전라남도 여수시 성산로 5 (화장동)
#    → ❌ 위경도 찾을 수 없음
# [61/100] 주소: 전라남도 광양시 광양읍 인동리 411번지 10호 (3층)
#    → ❌ 위경도 찾을 수 없음
# [62/100] 주소: 전라남도 영암군 삼호읍 세가래1길 10-6
#    → 위도: 34.7480189, 경도: 126.4752938
# [63/100] 주소: 전라남도 강진군 신전면 운주로 331 (송천보건진료소)
#    → ❌ 위경도 찾을 수 없음
# [64/100] 주소: 전라남도 영암군 영암읍 오리정길 39
#    → ❌ 위경도 찾을 수 없음
# [65/100] 주소: 전라남도 강진군 대구면 계율길 41 (계율보건진료소)
#    → ❌ 위경도 찾을 수 없음
# [66/100] 주소: 전라남도 광양시 광영로 46 (광영동)
#    → ❌ 위경도 찾을 수 없음
# [67/100] 주소: 전라남도 광양시 광양읍 숲샘길 129
#    → 위도: 34.9708239, 경도: 127.5853624
# [68/100] 주소: 전라남도 목포시 청호로 172, 3층 (산정동)
#    → ❌ 위경도 찾을 수 없음
# [69/100] 주소: 전라남도 목포시 영산로 347 (용해동)
#    → ❌ 위경도 찾을 수 없음
# [70/100] 주소: 전라남도 목포시 부흥로 80, 3층 (옥암동)
#    → ❌ 위경도 찾을 수 없음
# [71/100] 주소: nan
#    → 위도: 34.220389, 경도: 70.3800314
# [72/100] 주소: 전라남도 여수시 남면 금오로 858
#    → 위도: 34.5276261, 경도: 127.769361
# [73/100] 주소: 전라남도 목포시 상동 991-2번지
#    → ❌ 위경도 찾을 수 없음
# [74/100] 주소: 전라남도 목포시 연산동 1262-2번지 2층
#    → ❌ 위경도 찾을 수 없음
# [75/100] 주소: 전라남도 여수시 화양면 화양로 1436-5
#    → 위도: 34.7347, 경도: 127.6225471
# [76/100] 주소: 전라남도 순천시 왕지로 39, 3층 (왕지동)
#    → ❌ 위경도 찾을 수 없음
# [77/100] 주소: 전라남도 강진군 강진읍 평동2길 30, 2층 202호 (지스퀘어2층)
#    → ❌ 위경도 찾을 수 없음
# [78/100] 주소: 전라남도 순천시 해룡면 향매로 67, 4층
#    → ❌ 위경도 찾을 수 없음
# [79/100] 주소: 전라남도 여수시 여서1로 62 (여서동)
#    → ❌ 위경도 찾을 수 없음
# [80/100] 주소: 전라남도 여수시 쌍봉로 372 (둔덕동)
#    → ❌ 위경도 찾을 수 없음
# [81/100] 주소: 전라남도 목포시 영산로 559, 2층 (상동)
#    → ❌ 위경도 찾을 수 없음
# [82/100] 주소: 전라남도 화순군 화순읍 교리 100번지 10호
#    → ❌ 위경도 찾을 수 없음
# [83/100] 주소: 전라남도 순천시 오천7길 28, 4층 401호 (오천동)
#    → ❌ 위경도 찾을 수 없음
# [84/100] 주소: 전라남도 화순군 화순읍 교리 100번지 14호
#    → ❌ 위경도 찾을 수 없음
# [85/100] 주소: 전라남도 화순군 화순읍 칠충로 145
#    → 위도: 35.061523, 경도: 126.9837294
# [86/100] 주소: 전라남도 화순군 화순읍 자치샘로 48, 204,205호 (미래타워)
#    → ❌ 위경도 찾을 수 없음
# [87/100] 주소: 전라남도 화순군 화순읍 향청리 83번지 1호
#    → ❌ 위경도 찾을 수 없음
# [88/100] 주소: 전라남도 목포시 용해지구로 12, 2층 (용해동)
#    → ❌ 위경도 찾을 수 없음
# [89/100] 주소: 전라남도 화순군 춘양면 석정리 573번지 16호
#    → ❌ 위경도 찾을 수 없음
# [90/100] 주소: 전라남도 여수시 봉산동 269-43
#    → 위도: 34.7351874, 경도: 127.7230575
# [91/100] 주소: 전라남도 여수시 문수동 479-1
#    → ❌ 위경도 찾을 수 없음
# [92/100] 주소: 전라남도 장성군 장성읍 영천로 125-1
#    → ❌ 위경도 찾을 수 없음
# [93/100] 주소: 전라남도 장성군 장성읍 영천로 208-1
#    → ❌ 위경도 찾을 수 없음
# [94/100] 주소: 전라남도 장성군 장성읍 영천로 128
#    → ❌ 위경도 찾을 수 없음
# [95/100] 주소: 전라남도 완도군 보길면 청별길 26-2, 보길면 복지회관 1층
#    → ❌ 위경도 찾을 수 없음
# [96/100] 주소: 전라남도 목포시 비파로51번길 31, 2층 (상동)
#    → ❌ 위경도 찾을 수 없음
# [97/100] 주소: 전라남도 보성군 보성읍 현충로 23-1
#    → 위도: 34.7679367, 경도: 127.0823852
# [98/100] 주소: 전라남도 완도군 생일면 생일로 590-32
#    → 위도: 34.3371125, 경도: 126.9956297
# [99/100] 주소: 전라남도 순천시 황전면 괴목길 97
#    → ❌ 위경도 찾을 수 없음
# [100/100] 주소: 전라남도 순천시 연향중앙상가길 29 (연향동)
#    → ❌ 위경도 찾을 수 없음
# 총 오류 수: 76

# %%
import requests
import pandas as pd
from geopy.distance import geodesic

REST_API_KEY = "c6167fc9bb70ca9ea487094d849bb1f5"  # 여기에 본인의 REST 키 삽입

headers = {"Authorization": f"KakaoAK {REST_API_KEY}"}
center_lat = 34.9506
center_lon = 127.4872
radius = 5000

category_codes = {
    "음식점": "FD6",
    "편의점": "CS2",
    "공공기관": "PO3"
}

results = []

def search_nearby(category_name, category_code):
    url = "https://dapi.kakao.com/v2/local/search/category.json"
    params = {
        "category_group_code": category_code,
        "x": str(center_lon),   # 반드시 문자열!
        "y": str(center_lat),
        "radius": radius,
        "size": 15
    }

    r = requests.get(url, headers=headers, params=params)
    print(f"{category_name} 상태 코드:", r.status_code)  # 확인용

    if r.status_code == 200:
        for doc in r.json()["documents"]:
            coord = (float(doc["y"]), float(doc["x"]))
            dist = geodesic((center_lat, center_lon), coord).meters
            results.append({
                "이름": doc["place_name"],
                "주소": doc["road_address_name"],
                "위도": doc["y"],
                "경도": doc["x"],
                "거리(m)": int(dist),
                "카테고리": category_name
            })
    else:
        print(f"{category_name} 검색 실패:", r.text)

for name, code in category_codes.items():
    search_nearby(name, code)

df = pd.DataFrame(results)
print(df.head())
df.to_csv("전남_시설_검색결과.csv", index=False, encoding="utf-8-sig")
# Out:
# 음식점 상태 코드: 200
# 편의점 상태 코드: 200
# 공공기관 상태 코드: 200
#          이름                 주소                 위도                  경도  거리(m)  \
# 0      대원식당  전남 순천시 장천2길 30-29  34.95010189963333  127.49017155220966    276
# 1  순천한정식명궁관      전남 순천시 중앙2길 7  34.94982875785895  127.48614014933086    129
# 2       화월당    전남 순천시 중앙로 90-1  34.95369370195599  127.48415181634455    441
# 3      풍미통닭      전남 순천시 성남뒷길 3  34.94634542197918  127.49094723338463    583
# 4      금빈회관      전남 순천시 장명4길 8   34.9515012377406      127.4880582123    127
#
#   카테고리
# 0  음식점
# 1  음식점
# 2  음식점
# 3  음식점
# 4  음식점

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

df = pd.read_csv("./데이터/주소위도경도.csv", encoding="utf-8")

# 🔹 위도/경도/이름 컬럼 자동 탐색
lat_col = next((c for c in df.columns if "위도" in c or "lat" in c.lower()), None)
lon_col = next((c for c in df.columns if "경도" in c or "lon" in c.lower()), None)
name_col = next((c for c in df.columns if "폐교명" in c or "name" in c.lower()), None)

if not lat_col or not lon_col:
    raise ValueError("❌ 위도/경도 컬럼이 존재하지 않습니다.")

# 🔹 중심 좌표 계산
df = df.dropna(subset=[lat_col, lon_col])
df[lat_col] = df[lat_col].astype(float)
df[lon_col] = df[lon_col].astype(float)
center = [df[lat_col].mean(), df[lon_col].mean()]

# 🔹 Folium 지도 생성
m = folium.Map(location=center, zoom_start=8, tiles="CartoDB positron")
marker_cluster = MarkerCluster().add_to(m)

# 🔹 마커 추가
for _, row in df.iterrows():
    lat = row[lat_col]
    lon = row[lon_col]
    popup = row[name_col] if name_col else f"{lat}, {lon}"
    folium.Marker([lat, lon], popup=popup).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ad8c9c3e69ad699761a3051a7154557 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ad8c9c3e69ad699761a3051a7154557&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ad8c9c3e69ad699761a3051a7154557 = L.map(
#                 &quot;map_2ad8c9c3e69ad699761a3051a7154557&quot;,
#                 {
#                     center: [34.826788003305786, 127.06929468099175],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0278e6baeece6d1c7d734d728f847fdd = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0278e6baeece6d1c7d734d728f847fdd.addTo(map_2ad8c9c3e69ad699761a3051a7154557);
#
#
#             var marker_cluster_81771fc5329b05b685d8e98e6a40e94f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_33cd9babf793a0e209bd3360f9a3de3b = L.marker(
#                 [34.8030682, 126.3225411],
#                 {
# }
#             ).addTo(marker_cluster_81771fc5329b05b685d8e98e6a40e94f);
#
#
#         var popup_d2836a5105f11dca9b05ef02fbfd0f28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26dc69c6137ff0d6264d72c969a9ce3a = $(`&lt;div id=&quot;html_26dc69c6137ff0d6264d72c969a9ce3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;유달초율도분교장&lt;/div&gt;`)[0];
#                 popup_d2836a5105f11dca9b05ef02fbfd0f28.setContent(html_26dc69c6137ff0d6264d72c969a9ce3a);
#
#
#
#         marker_33cd9babf793a0e209bd3360f9a3de3b.bindPopup(popup_d2836a5105f11dca9b05ef02fbfd0f28)
#         ;
#
#
#
#
#             var marker_c50594b05d6fbaf8c10588d62a52b5b0 = L.marker(
#                 [34.7619469, 126.367369],
#                 {
# }
#             ).addTo(marker_cluster_81771fc5329b05b685d8e98e6a40e94f);
#
#
#         var popup_f0954d6c58a629b3c08dbc1c19f01f5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02f8c02055eb5469e0f384e68b1868bb = $(`&lt;div id=&quot;html_02f8c02055eb5469e0f384e68b1868bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;목포서산초 충무분교장&lt;/div&gt;`)[0];
#                 popup_f0954d6c58a629b3c08dbc1c19f01f5e.setContent(html_02f8c02055eb5469e0f384e68b1868bb);
#
#
#
#         marker_c50594b05d6fbaf8c10588d62a52b5b0.bindPopup(popup_f0954d6c58a629b3c08dbc1c19f01f5e)
#         ;
#
#
#
#
#             var marker_5d6d2f6ceb50f1cd419c49aa4f096570 = L.marker(
#                 [34.7142396, 127.7769028],
#                 {
# }
#             ).addTo(marker_cluster_81771fc5329b05b685d8e98e6a40e94f);
#
#
#         var popup_5801bfb921b8ffa16efe56bd6639aa47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a71341e30a24a9f754ebf0eb799da376 = $(`&lt;div id=&quot;html_a71341e30a24a9f754ebf0eb799da376&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;백초초우두분교장&lt;/div&gt;`)[0];
#                 popup_5801bfb921b8ffa16efe56bd6639aa47.setContent(html_a71341e30a24a9f754ebf0eb799da376);
#
#
#
#         marker_5d6d2f6ceb50f1cd419c49aa4f096570.bindPopup(popup_5801bfb921b8ffa16efe56bd6639aa47)
#         ;
#
#
#
#
#             var marker_959650820aeaadd6cbc72f3997c8e81d = L.marker(
#                 [34.4848853, 127.8057623],
#                 {
# }
#             ).addTo(marker_cluster_81771fc5329b05b685d8e98e6a40e94f);
#
#
#         var popup_3854cfca52a36bb556908ef54d81403f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6795d3c5875d7909ed29c25002e56801 = $(`&lt;div id=&quot;html_6795d3c5875d7909ed29c25002e56801&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;여안초여남중안도분교장&lt;/div&gt;`)[0];
#                 popup_3854cfca52a36bb556908ef54d81403f.setContent(html_6795d3c5875d7909ed29c25002e56801);
#
#
#
#         marker_959650820aeaadd6cbc72f3997c8e81d.bindPopup(popup

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# 🔹 CSV 파일 불러오기 (경로에 맞게 수정)
try:
    df = pd.read_csv("./데이터/주소위도경도.csv", encoding="utf-8")
except UnicodeDecodeError:
    df = pd.read_csv("./데이터/주소위도경도.csv", encoding="cp949")

print(df.columns)      # 모든 컬럼명 확인
print(df.head())       # 몇 줄 미리보기
# Out:
# Index(['NO', '폐교명', '주소', '위도', '경도'], dtype='object')
#    NO          폐교명                                                 주소  \
# 0   1     유달초율도분교장                                 1 전라남도 목포시 율도동 261
# 1   2  목포서산초 충무분교장  2 전라남도 목포시 달동 800-8, 800-31, 800-15, 800-19, 8...
# 2   3     백초초우두분교장                             3 전라남도 여수시 돌산읍 우두리 170
# 3   4  여안초여남중안도분교장                            4 전라남도 여수시 남면 안도리 999-3
# 4   5       초도초등학교                            5 전라남도 여수시 삼산면 초도리 산456
#
#           위도          경도
# 0  34.803068  126.322541
# 1  34.761947  126.367369
# 2  34.714240  127.776903
# 3  34.484885  127.805762
# 4  34.236548  127.249686

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import re

df = pd.read_csv("./데이터/주소위도경도.csv", encoding="utf-8")

print(df.columns)
print(df.head())
# Out:
# Index(['NO', '폐교명', '주소', '위도', '경도', '음식점 수', '편의점 수', '카페 수', '병원 수',
#        '주유소/충전소 수', '숙박시설 수'],
#       dtype='object')
#    NO          폐교명                                                 주소  \
# 0   1     유달초율도분교장                                   전라남도 목포시 율도동 261
# 1   2  목포서산초 충무분교장  전라남도 목포시 달동 800-8, 800-31, 800-15, 800-19, 800...
# 2   3     백초초우두분교장                               전라남도 여수시 돌산읍 우두리 170
# 3   4  여안초여남중안도분교장                              전라남도 여수시 남면 안도리 999-3
# 4   5       초도초등학교                              전라남도 여수시 삼산면 초도리 산456
#
#           위도          경도  음식점 수  편의점 수  카페 수  병원 수  주유소/충전소 수  숙박시설 수
# 0  34.803068  126.322541      1      0     0     0          0      10
# 1  34.761947  126.367369    261     21    64     6          8      37
# 2  34.714240  127.776903    171     20    41     3          3     140
# 3  34.484885  127.805762      7      0     0     0          0      30
# 4  34.236548  127.249686      2      0     0     0          0       3
